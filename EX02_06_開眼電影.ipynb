# %% [markdown]
# <a href="https://colab.research.google.com/github/noble752/nsysuhomework/blob/main/EX02_06_%E9%96%8B%E7%9C%BC%E9%9B%BB%E5%BD%B1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup
url = 'http://www.atmovies.com.tw/movie/next/'
response = requests.get(url)
response.encoding = 'utf-8'
soup = BeautifulSoup(response.text, 'lxml')
soup.title
# Out:
# <title>開眼電影網首頁--近期上映--</title>

# %%
import os
import csv
if not os.path.exists('/content/movies'):
  os.mkdir('/content/movies')

movies = [['電影:','上映日期:']]

for mv in soup.find('ul', class_='filmListAllX').find_all('li'):
    ttl = mv.img['alt']
    src = mv.img['src']
    src =src[1:]
    dat = mv.find('div', class_='runtime').text
    dat = dat[5:15]
    movies.append([ttl, dat])
    print(ttl, src, dat)
    # !wget -O /content/movies/{ttl}.jpg {src}
    #with open(f'/content/movies/{ttl}.jpg','wb') as f:
    #  f.write(requests.get(src).content)

with open('/content/movies/movies.csv', 'w', newline='') as f:
  w = csv.writer(f)
  w.writerows(movies)
# Out:
# 我依然在此 http://www.atmovies.com.tw/photo101/fipt14961016/pl_fipt14961016_0002.jpg  2025/04/02
# --2025-03-25 08:21:05--  http://www.atmovies.com.tw/photo101/fipt14961016/pl_fipt14961016_0002.jpg
# Resolving www.atmovies.com.tw (www.atmovies.com.tw)... 61.61.96.231
# Connecting to www.atmovies.com.tw (www.atmovies.com.tw)|61.61.96.231|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 78018 (76K) [image/jpeg]
# Saving to: ‘/content/movies/我依然在此.jpg’
#
# /content/movies/我  100%[===================>]  76.19K  97.4KB/s    in 0.8s
#
# 2025-03-25 08:21:07 (97.4 KB/s) - ‘/content/movies/我依然在此.jpg’ saved [78018/78018]
#
# MINECRAFT麥塊電影 http://www.atmovies.com.tw/photo101/faen83566834/pl_faen83566834_0005.jpg  2025/04/02
# --2025-03-25 08:21:07--  http://www.atmovies.com.tw/photo101/faen83566834/pl_faen83566834_0005.jpg
# Resolving www.atmovies.com.tw (www.atmovies.com.tw)... 61.61.96.231
# ...
